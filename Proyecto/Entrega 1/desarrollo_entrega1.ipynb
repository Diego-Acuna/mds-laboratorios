# %% [markdown]
# ![](https://www.dii.uchile.cl/wp-content/uploads/2021/06/Magi%CC%81ster-en-Ciencia-de-Datos.png)

# %% [markdown]
# **MDS7202: Laboratorio de Programación Científica para Ciencia de Datos**
#
# ### 👨‍🏫👩‍🏫 Cuerpo Docente:
#
# - Profesores: Diego Cortez, Gabriel Iturra
# - Auxiliares: Melanie Peña, Valentina Rojas
# - Ayudantes: Nicolás Cabello, Cristopher Urbina
#
# ### 👨‍💻👩‍💻 Estudiantes:
# - Estudiante n°1: Diego Acuña
# - Estudiante n°2: Tomás Ramírez
#
# _Por favor, lean detalladamente las instrucciones de la tarea antes de empezar a escribir._
#
# ---

# %% [markdown]
# ---
#
# ## 📖 Enunciado

# %% [markdown]
# <div align="center">
#     <img src='https://github.com/MDS7202/MDS7202/blob/main/recursos/2025-01/proyecto/proyecto.png?raw=true' style="border-radius: 12px">
# </div>

# %% [markdown]
# En el competitivo universo de las bebidas gaseosas, la empresa **SodAI Drinks 🥤** ha logrado destacarse por su creatividad, diversidad de productos y enfoque centrado en el cliente. Ofrece una extensa gama de bebidas carbonatadas que abarca distintos segmentos del mercado: desde productos premium en presentaciones sofisticadas, hasta gaseosas accesibles para el consumo masivo, disponibles en diversos tamaños y tipos de envases.
#
# La compañía opera en múltiples regiones y zonas, sirviendo a una variedad de puntos de venta que incluyen desde tiendas de conveniencia y minimarkets hasta el canal frío tradicional. Cada tipo de cliente tiene sus particularidades: algunos reciben entregas hasta 4 veces por semana, mientras que otros son visitados por la fuerza de ventas solo una vez semanalmente. Esta diversidad de perfiles representa tanto una oportunidad como un desafío comercial: ¿cómo saber qué productos tienen más chances de ser comprados por cada cliente en un momento dado?
#
# Con el objetivo de aumentar la facturación de forma inteligente y mejorar la eficiencia de su estrategia de ventas, **SodAI Drinks** decide crear una nueva célula interna de innovación: el equipo **Deep Drinkers 🤖**, cuyo propósito es aplicar ciencia de datos para anticiparse a las necesidades del cliente y potenciar el negocio desde una perspectiva basada en información.
#
# El corazón de esta iniciativa es el desarrollo de un sistema predictivo personalizado para cada cliente. Para ello, **Deep Drinkers** convoca a un equipo de Data Scientists y especialistas en *machine learning* con una misión clara: construir un modelo predictivo que, cada semana, pueda estimar la probabilidad de compra de cada producto del portafolio para cada cliente activo.
#
# El modelo deberá tener en cuenta múltiples factores, incluyendo:
# - **Tipo de cliente**, ej. "TIENDA DE CONVENIENCIA", "MINIMARKET".
# - **Frecuencia de entregas y visitas**, indicadores del nivel de actividad comercial.
# - **Ubicación geográfica** (por región y zona).
# - **Preferencias históricas de consumo**, inferidas por patrones de compra anteriores.
# - **Características del producto**, como marca, categoría, segmento, tipo de envase y tamaño
#
# El objetivo final es que, **cada semana**, se genere una tabla de productos priorizados: para cada cliente, un listado de productos ordenado por su probabilidad estimada de compra. Esta información será enviada al equipo comercial, que podrá usarla en call center, para incrementar las chances de concretar ventas al ofrecer justo lo que el cliente probablemente quiere comprar.
#
# Este proyecto representa un cambio de paradigma en la forma en que **SodAI Drinks** gestiona su fuerza de ventas: de un enfoque reactivo y generalista, a uno proactivo, basado en datos y profundamente personalizado. Así, la empresa no solo espera aumentar su rentabilidad, sino también construir relaciones más sólidas con sus clientes, ofreciéndoles recomendaciones más relevantes y oportunas.
#
# Para lograr lo anterior, el equipo **Deep Drinkers** contará con los siguientes conjuntos de datos, junto a sus respectivos atributos:
#
# - **Datos transaccionales** (`transacciones.parquet`): contiene el historial de compras realizadas por los clientes.
# 	- `customer_id`: identificador único del cliente que realizó la compra.
# 	- `product_id`: identificador único del producto comprado.
# 	- `purchase_date`: fecha en que se realizó la transacción.
# 	- `order_id`: identificar de la orden de su pedido.
# 	- `payment`	monto total pagado por la transacción.
#
# - **Datos de clientes** (`clientes.parquet`): incluye las características de cada cliente.
# 	- `customer_id`: identificador único del cliente.
# 	- `region_id`: identificador de la región geográfica donde se encuentra el cliente.
# 	- `customer_type`: tipo de cliente según el canal comercial, por ejemplo, “TIENDA DE CONVENIENCIA”.
# 	- `Y`: coordenada geográfica de latitud.
# 	- `X`: coordenada geográfica de longitud.
# 	- `num_deliver_per_week`: cantidad de entregas semanales que recibe el cliente.
# 	- `num_visit_per_week`: frecuencia de visitas de la fuerza de ventas por semana.
#
# - **Datos de productos** (`productos.parquet`): describe las características de los productos del portafolio.
# 	- `product_id`: identificador único del producto.
# 	- `brand`: marca comercial del producto.
# 	- `category`: categoría general del producto, como “BEBIDAS CARBONATADAS”.
# 	- `sub_category`: subcategoría dentro de la categoría principal, por ejemplo, “GASEOSAS”.
# 	- `segment`: segmento de mercado al que pertenece el producto, como “PREMIUM”.
# 	- `package`: tipo de envase del producto.
# 	- `size`: tamaño del producto en litros.

# %% [markdown]
# ## 📚 Reglas

# %% [markdown]
# <center>
# <img src="https://media1.tenor.com/m/0Qtv_cQ4ITsAAAAd/necohaus-grey-name.gif" width="450">

# %% [markdown]
# El proyecto consta de **dos entregas parciales** y una **entrega final** en donde la primera entrega la idea es poder reflejar lo aprendido durante la primera mitad del curso, que será sobre los contenidos relacionados a *machine learning*, la segunda será sobre los contenidos de la segunda mitad del curso relacionados a *MLOps* y por último la entrega final constará de dos partes, donde la primera será relacionada con experimentación sobre nuevos datasets que serán disponibilizados durante las últimas semanas del curso de manera incremental y una segunda parte que será el informe final escrito que deberá explicar el desarrollo del proyecto completo, como tambien los resultados y análisis de los experimentos realizados sobre los datasets incrementales. La idea es que todo el código esté desarrollado durante las primeras dos entregas y luego en la entrega final sólo se ejecute el código sobre nuevos conjuntos de datos.
#
# La idea de generar el proyecto por etapas es poder aliviar la carga de trabajo en las últimas semanas del semestre donde sabemos que están muy cargado con entregas, pruebas y exámenes de otros ramos, y así garantizamos que habiendo la desarrollado las dos primeras entregas parciales, tendrán el grueso del proyecto listo para luego experimentar y documentar.
#
# ---
# ### **Fechas de entrega**
# - **Entrega parcial 1**: 7 de octubre
# - **Entrega parcial 2**: Por definir
# - **Entrega final**: Por definir
#
# ---
#
# ### **Requisitos del proyecto**
# - **Grupos**: Formar equipos de **2 personas**. No se aceptarán trabajos individuales o grupos con más integrantes.
# - **Consultas**: Cualquier duda fuera del horario de clases debe ser planteada en el foro correspondiente. Los mensajes enviados al equipo docente serán respondidos únicamente por este medio. Por favor, revisen las respuestas anteriores en el foro antes de realizar nuevas consultas.
# - **Plagio**: La copia o reutilización no autorizada de trabajos de otros grupos está **estrictamente prohibida**. El incumplimiento de esta norma implicará la anulación inmediata del proyecto y una posible sanción académica.
# - **Material permitido**: Pueden usar cualquier material del curso, ya sea notas, lecturas, códigos, o referencias proporcionadas por los docentes, que consideren útil para el desarrollo del proyecto.
#
# ---
#
# ### **Entregables y etapas**
#
# #### **1. Entrega Parcial 1**
# - Dispondrán de los archivos de datos **productos.parquet**, **clientes.parquet** y **transacciones.parquet** para el modelamiento inicial.
# - Utilizarán estos archivos para desarrollar lo solicitado para la entrega 1.
# - En esta etapa, se espera que apliquen todos los conocimientos aprendidos durante la primera parte del curso relacionados con *machine learning*.
# - **Informe**: No se exige un avance del informe en esta etapa, sólo un notebook con su desarrollo actual, pero se **recomienda comenzar** a redactar el informe final en paralelo para disminuir la carga académica en las etapas posteriores.
#
# #### **2. Entrega Parcial 2**
# - En esta entrega, deberán aplicar los conocimientos aprendidos durante la segunda mitad del curso sobre *MLOps*
# - Se espera que implementen estos conocimientos para desplegar su modelo elegido en la primera entrega y crear *pipelines* automatizados que simulen un entorno productivo.
# - **Informe**: similar a la primera etapa, no se exige un avance del informe, pero se **recomienda avanzar con su redacción** para evitar una acumulación de trabajo en la etapa final.
#
# #### **3. Entrega Final**
# - En la entrega final, deberán realizar dos etapas:
# 	- La primera etapa es sobre experimentación utilizando datasets incrementales que se irán disponibilizando de manera parcial, para que vayan generando predicciones con su modelo ya desplegado. El objetivo de esta etapa es poder testear su solución *end-to-end* y que vayan analizando los resultados obtenidos a medida que se van agregando más datos.
# 	- La segunda etapa consiste en redactar un informe final que deberá explicar el desarrollo completo de tu proyecto y un análisis profundo de sus resultados de experimentación. Este informe debera incluir a lo menos las siguientes secciones:
# 		- Análisis exploratorio de datos
# 		- Metodología aplicada
# 		- Selección y entrenamiento de modelos
# 		- Evaluación de resultados
# 		- Optimización de modelos
# 		- Interpretabilidad
# 		- Re-entrenamiento
# 		- Tracking con MLFlow
# 		- Creación de la aplicación web con Gradio y FastAPI
#
# Es **altamente recomendable** ir redactando el informe en paralelo al desarrollo de los modelos para garantizar que toda la información relevante quede documentada adecuadamente.
#
# ### Nota Final
#
# La calificación final de su proyecto se calculará utilizando la siguiente ponderación:
#
# $$Nota Final = 0.30 * EntregaParcial1 + 0.40 * EntregaParcial2 + 0.30 * EntregaFinal$$
#
# ---
#
# ### **Instrucciones importantes**
#
# 1. **Formato del informe**:
#    - El informe debe estar integrado dentro de un **Jupyter Notebook**. No es necesario subirlo a una plataforma externa, pero debe cumplir con los siguientes requisitos:
#      - Estructura clara y ordenada.
#      - Código acompañado de explicaciones detalladas.
#      - Resultados presentados de forma visual y analítica.
#
# 2. **Descuento por informes deficientes**:
#    - Cualquier sección del informe que no tenga una explicación adecuada o no respete el formato será penalizada con un descuento en la nota. Esto incluye código sin comentarios o análisis que no sean coherentes con los resultados presentados.
#    - Comentarios sin formatear de ChatGPT o herramientas similares serán penalizados (e.g: "Inserta tu modelo acá", etc.)

# %% [markdown]
# # 📬 Entrega Parcial 1 (30% del Proyecto)

# %% [markdown]
# ### 📪 Fecha de Entrega: 7 de Octubre

# %% [markdown]
# ## 📌 Abstract [0.25 puntos]
#
# <center>
# <img src="https://i.redd.it/h5ptnsyabqvd1.gif" width="400" height="300">

# %% [markdown]
# En esta sección, deben redactar un Abstract claro y conciso para su proyecto. El Abstract debe responder a las siguientes preguntas clave:
#
# - **Descripción del problema**: ¿Cuál es el objetivo del proyecto? ¿Qué se intenta predecir o analizar?
# - **Datos de entrada**: ¿Qué datos tienen disponibles? ¿Cuáles son sus principales características?
# - **Métrica de evaluación**: ¿Cómo medirán el desempeño de sus modelos? Expliquen por qué eligieron esta métrica basándose en el análisis exploratorio de los datos.
# - **Modelos y transformaciones**: ¿Qué modelos utilizarán y por qué? ¿Qué transformaciones o preprocesamientos aplicaron a los datos?
# - **Resultados generales**: ¿El modelo final cumplió con los objetivos del proyecto? ¿Cuáles fueron las conclusiones más importantes?
#
# **Importante**: Escriban esto despues de haber resuelto el resto de la tarea.

# %% [markdown]
# ### Abstract
#
# Este trabajo desarrolla un sistema de predicción semanal de propensión de compra por cliente–producto para SodAI Drinks, con el fin de priorizar el portafolio que el equipo comercial ofrece a cada punto de venta. El objetivo es estimar, cada semana, la probabilidad de compra de cada SKU por cliente y ordenar dichas probabilidades para apoyar llamadas y ofertas dirigidas.
#
# **Datos de entrada.** Se integró el historial transaccional, el maestro de clientes y el de productos en una matriz cliente–producto–semana (53 semanas). Tras el pre-procesamiento y el cruce, se generaron 59 atributos que combinan: señales de recencia y frecuencia (p. ej., `cp_recency`, `cp_count_4w`, `cp_count_12w`), tasa histórica SKU×cliente (`prod_prior_rate`), banderas de compra previa, y codificación One-Hot de variables categóricas (con agrupación de categorías raras). Las particiones se definieron temporalmente con purga: *train* hasta 2024-08-26, *valid* 2024-09-09 a 2024-10-21 y *test* 2024-11-04 a 2024-12-30.
#
# **Métrica de evaluación.** La métrica principal fue PR-AUC (área precisión–recall), adecuada para nuestra tarea de priorización y para manejar el desbalance, complementada con AUC-ROC y un umbral óptimo por F1 seleccionado en *valid* y aplicado a *test*.
#
# **Modelos y transformaciones.** Se compararon modelos lineales y de árboles de *boosting* dentro de *pipelines* reproducibles. El mejor desempeño lo entregó LightGBM, tras una optimización con Optuna que incluyó hiperparámetros del modelo y del preprocesamiento (imputación, *scaling*, OHE con *rare-categories*).
#
# **Resultados generales.** El modelo final logró PR-AUC 0.96196 (VALID) y 0.96528 (TEST), con AUC-ROC ≈ 0.97 y alta recuperación al umbral F1 seleccionado. La interpretabilidad con SHAP confirmó como principales impulsores recencia, frecuencia y tasa histórica, y reveló efectos de ciertos categóricos (p. ej., `customer_type_nan`, `region_id_80`) que se monitorizarán por posible dependencia operativa. En conjunto, la solución generaliza de forma estable y habilita una priorización semanal accionable para incrementar la efectividad comercial.

# %% [markdown]
# ## 📌 Pre-procesamiento [0.5 puntos]
#
# <center>
# <img src="https://media0.giphy.com/media/10zsjaH4g0GgmY/giphy.gif?cid=6c09b9523xtlunksc9amikw09zk1bmiqwjqnt70ae82rk877&ep=v1_gifs_search&rid=giphy.gif&ct=g" width="400" height="300">

# %% [markdown]
# Tal como en muchos otros problemas de negocio, los datos probablemente deben ser pre procesados antes de aplicar cualquier técnica de analítica. Bajo esa premisa, en esta sección deben desarrollar código que les permita **preparar los datos** de tal forma que les permita resolver el problema planteado. Para esto, pueden aplicar procesamientos como:
#
# - Transformaciones de tipo de dato (str, int, etc)
# - Cruce de información
# - Eliminación de duplicados
# - Filtros de fila y/o columnas
#
# *Hint: ¿Qué forma debería tener la data para resolver un problema de aprendizaje supervisado?*
#
# Todo proceso llevado a cabo debe estar bien documentado y justificado en el informe, explicando el por qué se decidió realizar en funcion de los datos presentados y los objetivos planteados del proyecto.

# %%
# Importamos librerías
import os
import re
import json
import platform
import time
from pathlib import Path
from joblib import dump
from datetime import datetime

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
from IPython.display import display

import sklearn
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, RobustScaler, StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, HistGradientBoostingClassifier
from sklearn.metrics import (
    classification_report,
    confusion_matrix,
    roc_auc_score,
    average_precision_score,
    precision_recall_curve,
)

from lightgbm import LGBMClassifier, early_stopping, log_evaluation

import optuna
from optuna.samplers import TPESampler
from optuna.pruners import MedianPruner

import shap

from joblib import dump, load

# %%
# Configuración de entradas/salidas
PATH_CLIENTES = "clientes.parquet"
PATH_PRODUCTOS = "productos.parquet"
PATH_TRANS     = "transacciones.parquet"

OUT_TRANS_CLEAN = "transacciones_limpio.parquet"
OUT_WEEKLY      = "interacciones_semana.parquet"

# ---------------------------
# Utilidades de lectura
# ---------------------------
def _read_parquet(path):
    """Lectura Parquet (notebook de trabajo)."""
    return pd.read_parquet(path)

def _parse_liters(raw):
    """Extrae el valor numérico (en litros) desde textos como '2L', '2,5 l', etc."""
    if pd.isna(raw):
        return np.nan
    s = str(raw).strip().lower().replace(",", ".")
    m = re.search(r"([0-9]*\.?[0-9]+)", s)
    return float(m.group(1)) if m else np.nan

# ---------------------------
# Carga y tipificación
# ---------------------------
clientes  = _read_parquet(PATH_CLIENTES)
productos = _read_parquet(PATH_PRODUCTOS)
trans     = _read_parquet(PATH_TRANS)

# Normaliza nombres de columnas
clientes.columns  = [c.strip().lower() for c in clientes.columns]
productos.columns = [c.strip().lower() for c in productos.columns]
trans.columns     = [c.strip().lower() for c in trans.columns]

# Tipos y formatos en clientes
for col in ["customer_id","region_id","zone_id"]:
    if col in clientes:
        clientes[col] = clientes[col].astype(str).str.strip()
for col in ["num_deliver_per_week","num_visit_per_week"]:
    if col in clientes:
        clientes[col] = pd.to_numeric(clientes[col], errors="coerce").astype("Int64")
for col in ["y","x"]:
    if col in clientes:
        clientes[col] = pd.to_numeric(clientes[col], errors="coerce")
if "customer_type" in clientes:
    clientes["customer_type"] = clientes["customer_type"].astype(str).str.strip().str.upper()

# Tipos y formatos en productos
if "product_id" in productos:
    productos["product_id"] = productos["product_id"].astype(str).str.strip()
for col in ["brand","category","sub_category","segment","package"]:
    if col in productos:
        productos[col] = productos[col].astype(str).str.strip().str.upper()
if "size" in productos:
    productos["size_liters"] = productos["size"].apply(_parse_liters)

# Tipos y formatos en transacciones
for col in ["customer_id","product_id","order_id"]:
    if col in trans:
        trans[col] = trans[col].astype(str).str.strip()

# Fecha de compra (naive); la semana arrancará en lunes
if "purchase_date" in trans:
    trans["purchase_date"] = pd.to_datetime(trans["purchase_date"], errors="coerce")

# Cantidades: el dataset operativo usa 'items' (si existiera 'payment', se trata análogo)
if "items" in trans:
    trans["items"] = pd.to_numeric(trans["items"], errors="coerce")

# ---------------------------
# Limpieza y validaciones mínimas
# ---------------------------
# Filtra nulos críticos en llaves y fecha
for col in ["customer_id","product_id","purchase_date"]:
    if col in trans:
        trans = trans[~trans[col].isna()]

# Valores imposibles: items negativos -> NaN (quedarán fuera en agregación)
if "items" in trans:
    trans.loc[trans["items"] < 0, "items"] = np.nan

# Duplicados exactos a nivel de fila transaccional
key_cols = [c for c in ["customer_id","product_id","order_id","purchase_date","items"] if c in trans]
if key_cols:
    trans = trans.drop_duplicates(subset=key_cols, keep="first")

# Integridad referencial contra maestros de clientes y productos
cust_set = set(clientes["customer_id"].astype(str))
prod_set = set(productos["product_id"].astype(str))
mask_bad_c = ~trans["customer_id"].astype(str).isin(cust_set)
mask_bad_p = ~trans["product_id"].astype(str).isin(prod_set)
trans = trans[~mask_bad_c & ~mask_bad_p].copy()

# ---------------------------
# Agregación semanal y construcción del target
# ---------------------------
# Semana que inicia en lunes (weekday=0)
trans["week"] = (trans["purchase_date"] -
                 pd.to_timedelta(trans["purchase_date"].dt.weekday, unit="D")).dt.normalize()

# Agrega por cliente-producto-semana
agg_cols = {}
if "items" in trans:    agg_cols["items"]    = "sum"   # Qty semanal
if "order_id" in trans: agg_cols["order_id"] = "count" # Proxy de líneas

weekly = (trans
          .groupby(["customer_id","product_id","week"], as_index=False)
          .agg(agg_cols)
          .rename(columns={"items":"qty","order_id":"num_lines"}))

# Etiqueta supervisada: compra semanal (1) vs no compra (0)
weekly["bought"] = ((weekly.get("qty", pd.Series(0)).fillna(0) > 0) |
                    (weekly.get("num_lines", pd.Series(0)).fillna(0) > 0)).astype(int)

# ---------------------------
# Enriquecimiento con dimensiones
# ---------------------------
weekly_enriched = (weekly
                   .merge(clientes,  on="customer_id", how="left", validate="m:1")
                   .merge(productos, on="product_id",  how="left", validate="m:1"))

# ---------------------------
# Exportamos
# ---------------------------
weekly_enriched.to_parquet(OUT_WEEKLY, index=False)
trans.to_parquet(OUT_TRANS_CLEAN, index=False)

# ---------------------------
# Reporte breve
# ---------------------------
print("Registros transacciones (limpio):", len(trans))
print("Observaciones semanales (pos.~=compradas):", len(weekly_enriched))
print("Semanas distintas:", weekly_enriched["week"].nunique())
print("Cobertura clientes:", weekly_enriched["customer_id"].nunique(),
      "| productos:", weekly_enriched["product_id"].nunique())
# Out:
# Registros transacciones (limpio): 254012
# Observaciones semanales (pos.~=compradas): 206460
# Semanas distintas: 53
# Cobertura clientes: 1490 | productos: 114

# %% [markdown]
# ## 📌 EDA [0.5 puntos]
#
# <center>
# <img src="https://media3.giphy.com/media/v1.Y2lkPTc5MGI3NjExbHZ6aGdkd21tYTI3cW8zYWhyYW5wdGlyb2s3MmRzeTV0dzQ1NWlueiZlcD12MV9pbnRlcm5hbF9naWZfYnlfaWQmY3Q9Zw/3k1hJubTtOAKPKx4k3/giphy.gif" width="400" height="200">

# %% [markdown]
# En esta sección, se debe realizar un análisis exploratorio de los datos para comprender su estructura, detectar posibles problemas y obtener información relevante para el entrenamiento de los modelos. La idea es que puedan detectar **patrones en los datos** que les permitan resolver el problema con mayor facilidad.
#
# Se deben responder preguntas a partir de lo que puedan visualizar/obtener, por ejemplo:
#
# - Clientes y productos
#
#     - ¿Cuántos clientes únicos hay en el dataset?
#
#     - ¿Cuántos productos únicos se encuentran en los datos?
#
# - Periodo y frecuencia
#
#     - ¿De qué periodo es la información disponible?
#
#     - ¿Cuál es la frecuencia de los registros (diaria, semanal, mensual, etc.)?
#
# - Calidad de los datos
#
#     - ¿Existen valores nulos en el dataset? ¿Cuántos? ¿Cómo se pueden tratar?
#
#     - ¿Hay datos raros, como cantidades negativas o inconsistencias? Genere tests de validación para identificar estos problemas.
#
# - Patrones de compra
#
#     - ¿Cuántos productos compra en promedio cada cliente semana a semana?
#
#     - ¿Cuántas transacciones ha realizado cada cliente?
#
#     - ¿Cuál es el periodo de recompra promedio de cada SKU?

# %%
# ---------------------------
# Carga
# ---------------------------
CLIENTES_PATH  = "clientes.parquet"
PRODUCTOS_PATH = "productos.parquet"
TRANS_PATH     = "transacciones_limpio.parquet"
WEEKLY_PATH    = "interacciones_semana.parquet"

clientes  = pd.read_parquet(CLIENTES_PATH)
productos = pd.read_parquet(PRODUCTOS_PATH)
trans     = pd.read_parquet(TRANS_PATH)
weekly    = pd.read_parquet(WEEKLY_PATH)

for df in (clientes, productos, trans, weekly):
    df.columns = [c.strip().lower() for c in df.columns]

# Claves como string para evitar choques de tipos
for df in (productos, trans, weekly):
    if "product_id" in df:  df["product_id"]  = df["product_id"].astype(str)
for df in (clientes, trans, weekly):
    if "customer_id" in df: df["customer_id"] = df["customer_id"].astype(str)

# Fechas
if "purchase_date" in trans:
    trans["purchase_date"] = pd.to_datetime(trans["purchase_date"], errors="coerce")
if "week" in weekly:
    weekly["week"] = pd.to_datetime(weekly["week"], errors="coerce")

# ---------------------------
# Clientes y productos
# ---------------------------
n_clientes   = clientes["customer_id"].nunique()
n_productos  = productos["product_id"].nunique()
print(f"Clientes únicos: {n_clientes}")
print(f"Productos únicos: {n_productos}")

# ---------------------------
# Periodo y granularidad temporal
# ---------------------------
fecha_min = trans["purchase_date"].min()
fecha_max = trans["purchase_date"].max()
print(f"Periodo observado: {fecha_min.date()} — {fecha_max.date()}")

tx_por_dia = (trans.assign(day=trans["purchase_date"].dt.date)
                   .groupby("day", as_index=False).size())
tx_por_sem = (trans.assign(week_start=(trans["purchase_date"]
                                       - pd.to_timedelta(trans["purchase_date"].dt.weekday, unit="D")).dt.normalize())
                   .groupby("week_start", as_index=False).size())

print(f"Semanas distintas (weekly): {weekly['week'].nunique()}")
print(f"Días con evento (transacciones): {tx_por_dia['day'].nunique()}")

# Gráficos
plt.figure()
plt.plot(pd.to_datetime(tx_por_sem["week_start"]), tx_por_sem["size"])
plt.title("Volumen de transacciones por semana")
plt.xlabel("Semana")
plt.ylabel("# transacciones")
plt.tight_layout()
plt.show()

plt.figure()
plt.plot(pd.to_datetime(tx_por_dia["day"]), tx_por_dia["size"])
plt.title("Volumen de transacciones por día")
plt.xlabel("Día")
plt.ylabel("# transacciones")
plt.tight_layout()
plt.show()

# ---------------------------
# Calidad de datos (nulos y tests)
# ---------------------------
def null_profile(df, name):
    n = len(df)
    out = (df.isna().sum().to_frame("nulos")
             .assign(pct=lambda x: 100 * x["nulos"] / n)
             .reset_index()
             .rename(columns={"index":"columna"}))
    out.insert(0, "dataset", name)
    return out

perfil_nulos = pd.concat([
    null_profile(clientes,  "clientes"),
    null_profile(productos, "productos"),
    null_profile(trans,     "transacciones_limpio"),
    null_profile(weekly,    "interacciones_semana"),
], ignore_index=True)
display(perfil_nulos.head(20))

tests = pd.DataFrame({
    "test":[
        "sin_items_negativos_en_transacciones",
        "llaves_no_nulas_en_transacciones",
        "fechas_validas_en_transacciones",
        "unicidad_(customer,product,week)_en_weekly"
    ],
    "pass":[
        (("items" not in trans.columns) or (trans["items"].ge(0).all())),
        (trans["customer_id"].notna().all() and trans["product_id"].notna().all() and trans["purchase_date"].notna().all()),
        (trans["purchase_date"].ge(fecha_min).all() & trans["purchase_date"].le(fecha_max).all()),
        (weekly.duplicated(subset=["customer_id","product_id","week"]).sum() == 0),
    ]
})
display(tests)

# ---------------------------
# Patrones de compra
# ---------------------------

# ¿Cuántos productos compra en promedio cada cliente semana a semana?
prod_por_cli_week = (weekly
                     .groupby(["customer_id","week"], as_index=False)
                     .agg(prod_distintos=("product_id","nunique")))
promedio_por_cliente = (prod_por_cli_week
                        .groupby("customer_id", as_index=False)
                        .agg(promedio_semanal=("prod_distintos","mean")))
promedio_global = promedio_por_cliente["promedio_semanal"].mean()
mediana_global  = promedio_por_cliente["promedio_semanal"].median()
print(f"Promedio global de productos por cliente-semana: {promedio_global:.3f} | mediana por cliente: {mediana_global:.3f}")

# ¿Cuántas transacciones ha realizado cada cliente?
if "order_id" in trans.columns:
    tx_por_cliente = trans.groupby("customer_id", as_index=False).agg(transacciones=("order_id","nunique"))
else:
    tx_por_cliente = trans.groupby("customer_id", as_index=False).agg(transacciones=("purchase_date","count"))

stats_tx = tx_por_cliente["transacciones"].describe(percentiles=[.1,.5,.9]).rename({
    "mean":"mean", "50%":"median", "10%":"p10", "90%":"p90"
})
display(tx_por_cliente.sort_values("transacciones", ascending=False).head(20))
print(stats_tx)

# ¿Cuál es el periodo de recompra promedio de cada SKU?
# Definición: para cada (producto, cliente) ordenado por fecha, delta en días entre compras consecutivas.
cols = ["product_id","customer_id","purchase_date"]
df_ip = trans.loc[trans[cols].notna().all(axis=1), cols].sort_values(cols)
df_ip["delta_dias"] = (df_ip.groupby(["product_id","customer_id"])["purchase_date"]
                           .diff().dt.days)

repurchase_sku = (df_ip.dropna(subset=["delta_dias"])
                    .groupby("product_id", as_index=False)
                    .agg(repurchase_prom_dias=("delta_dias","mean"),
                         n_intercompras=("delta_dias","size"))
                    .merge(productos, on="product_id", how="left"))

# Tabla y ranking de más rápidos/lentos con soporte mínimo
display(repurchase_sku.head(50))
umbral = repurchase_sku["n_intercompras"].quantile(0.25) if len(repurchase_sku) else 0
rep_rapid = repurchase_sku.query("n_intercompras >= @umbral").sort_values("repurchase_prom_dias").head(10)
rep_lento = repurchase_sku.query("n_intercompras >= @umbral").sort_values("repurchase_prom_dias", ascending=False).head(10)
display(rep_rapid)
display(rep_lento)
# Out:
# Clientes únicos: 1569
# Productos únicos: 971
# Periodo observado: 2024-01-01 — 2024-12-31
# Semanas distintas (weekly): 53
# Días con evento (transacciones): 366
#                  dataset               columna  nulos       pct
# 0               clientes           customer_id      0  0.000000
# 1               clientes             region_id      0  0.000000
# 2               clientes               zone_id      0  0.000000
# 3               clientes         customer_type      0  0.000000
# 4               clientes                     y      0  0.000000
# 5               clientes                     x      1  0.063735
# 6               clientes  num_deliver_per_week      0  0.000000
# 7               clientes    num_visit_per_week      0  0.000000
# 8              productos            product_id      0  0.000000
# 9              productos                 brand      0  0.000000
# 10             productos              category      0  0.000000
# ...

# %% [markdown]
# **Clientes y productos**
#
# * Clientes únicos en maestros: 1.569
# * Productos únicos en maestros: 971
#
# **Periodo y frecuencia**
#
# * Periodo observado en transacciones: 2024-01-01 a 2024-12-31
# * Días con evento: 366 (año bisiesto)
# * Semanas distintas (tabla agregada semanal): 53
# * Frecuencia: el dataset transaccional es a nivel de evento/diario; para modelamiento usaremos la agregación semanal (53 semanas).
#
# **Calidad de datos**
#
# * Nulos totales (conteo) detectados:
#
#   * `clientes`: 1 nulo total (disperso).
#   * `productos`: 0.
#   * `transacciones_limpio`: 8.307 nulos totales (principalmente en `items` cuando no se reporta cantidad; esto no afecta agregación, pues la suma ignora `NaN`).
#   * `interacciones_semana`: 0 (tabla model-ready).
# * Negativos: 0 cantidades negativas residuales en `transacciones_limpio`.
# * Duplicados de (`customer_id`,`product_id`,`week`) en `interacciones_semana`: 0.
# * Todos los tests de validación definidos pasan.
#
# **Patrones de compra**
#
# * Promedio de productos distintos comprados por cliente–semana: 4.03 (mediana por cliente: 3.39).
# * Transacciones por cliente (distribución sobre el año): media 43.36, mediana 38, p10 12, p90 83, máx 228.
# * Recompra (intercompra) promedio por SKU
#
#   * SKUs con soporte (≥2 compras en alguna secuencia cliente–SKU): 106
#   * Promedio global de recompra (días): 24.27; mediana 20.78
#   * Rango observado (promedios por SKU): 0.0 a 132.0 días
#   * Con soporte mínimo (≥ P25 de `n_intercompras`), los SKUs más rápidos rondan 4–8 días, y los más lentos ~42–59 días.

# %% [markdown]
# ## 📌 Holdout [0.25 puntos]
#
# Para evaluar correctamente el modelo y garantizar su capacidad de generalización, se deben dividir los datos en tres conjuntos:
# - `Entrenamiento` : Para ajustar los parámetros.
# - `Validación`: Para optimizar hiperparámetros y seleccionar el mejor modelo.
# - `Prueba` : Para evaluar el rendimiento final en datos no vistos.
#
# 👀 **Hint**: *Recuerde que los datos tienen una temporalidad que debe considerarse al momento de separarlos, para evitar fugas de información. Es importante justificar la estrategia de partición elegida y visualizar la distribución temporal de los conjuntos generados*

# %%
# HOLDOUT TEMPORAL
WEEKLY_PATH     = "interacciones_semana.parquet"
OUT_WEEKS_SPLIT = "holdout_weeks.parquet"   # week → split

# ---------------------------
# Carga y preparación
# ---------------------------
weekly = pd.read_parquet(WEEKLY_PATH)
weekly.columns = [c.strip().lower() for c in weekly.columns]
weekly["week"] = pd.to_datetime(weekly["week"], errors="coerce")

weeks = (weekly["week"]
         .dropna()
         .sort_values()
         .drop_duplicates()
         .to_numpy())

n_weeks = weeks.size
assert n_weeks >= 10, "Hay muy pocas semanas para un holdout estable."

# ---------------------------
# Parámetros y conteos
# ---------------------------
prop_train, prop_valid, prop_test = 0.70, 0.15, 0.15
gap = 1  # semanas purgadas entre splits

# Semanas efectivas tras purgar exactamente 2*gap
n_eff = n_weeks - 2*gap
assert n_eff > 0, "n_eff <= 0: reduce el gap o revisa n_weeks."

# Conteos por proporción sobre n_eff
n_train = int(np.floor(n_eff * prop_train))
n_valid = int(np.floor(n_eff * prop_valid))
n_test  = n_eff - n_train - n_valid  # resto a test para asegurar suma exacta

# Asegura al menos 1 semana por split (si hay espacio)
mins = np.array([1,1,1])
curr = np.array([n_train, n_valid, n_test])
def _fix_counts(curr, mins):
    deficit = (mins - curr).clip(min=0).sum()
    if deficit == 0:
        return curr
    # Si falta, toma del split más grande
    order = np.argsort(-curr)  # desc
    for i in order:
        give = min(deficit, max(0, curr[i]-1))
        curr[i] -= give
        deficit -= give
        if deficit <= 0:
            break
    return np.maximum(curr, mins)

n_train, n_valid, n_test = _fix_counts(curr, mins).tolist()
assert (n_train + n_valid + n_test) == n_eff

# ---------------------------
# Construcción de índices
# ---------------------------
# Estructura: [TRAIN (n_train)] [GAP (gap)] [VALID (n_valid)] [GAP (gap)] [TEST (n_test)]
idx_train_start = 0
idx_train_end   = idx_train_start + n_train            # exclusivo
idx_valid_start = idx_train_end + gap
idx_valid_end   = idx_valid_start + n_valid            # exclusivo
idx_test_start  = idx_valid_end + gap
idx_test_end    = idx_test_start + n_test              # exclusivo

idx = np.arange(n_weeks)
train_idx = idx[idx_train_start:idx_train_end]
valid_idx = idx[idx_valid_start:idx_valid_end]
test_idx  = idx[idx_test_start:idx_test_end]

# Mapas vectorizados
split_arr = np.full(n_weeks, "gap", dtype=object)
split_arr[train_idx] = "train"
split_arr[valid_idx] = "valid"
split_arr[test_idx]  = "test"

holdout_weeks = pd.DataFrame({"week": weeks, "split": split_arr})
holdout_weeks = holdout_weeks.query("split != 'gap'").reset_index(drop=True)

# ---------------------------
# Chequeos de consistencia
# ---------------------------
assert holdout_weeks.groupby("week")["split"].nunique().max() == 1
assert holdout_weeks["week"].is_monotonic_increasing
assert set(holdout_weeks["split"].unique()) == {"train","valid","test"}

# ---------------------------
# Aplicación y resúmenes
# ---------------------------
weekly_split = weekly.merge(holdout_weeks, on="week", how="inner", validate="m:1")
summary_split = (weekly_split
                 .groupby("split", as_index=False)
                 .agg(rows=("week","size"),
                      weeks_distintas=("week","nunique"),
                      clientes=("customer_id","nunique"),
                      productos=("product_id","nunique"),
                      inicio=("week","min"),
                      termino=("week","max"))
                 .sort_values("inicio"))
print("=== RESUMEN HOLDOUT (corregido) ===")
print(summary_split)

# Serie semanal por split
serie_sem = (weekly_split.groupby(["week","split"], as_index=False)
                          .size()
                          .rename(columns={"size":"n"}))
pivot_sem = (serie_sem.pivot(index="week", columns="split", values="n")
                       .fillna(0).sort_index())
ax = pivot_sem.plot(figsize=(10,4))
ax.set_title("Observaciones por semana y split (corregido)")
ax.set_xlabel("Semana")
ax.set_ylabel("# observaciones")
plt.tight_layout()
plt.show()

# ---------------------------
# Persistencia del mapping
# ---------------------------
holdout_weeks.to_parquet(OUT_WEEKS_SPLIT, index=False)
# Out:
# === RESUMEN HOLDOUT (corregido) ===
#    split    rows  weeks_distintas  clientes  productos     inicio    termino
# 1  train  124553               35      1397         99 2024-01-01 2024-08-26
# 2  valid   30702                7      1354         72 2024-09-09 2024-10-21
# 0   test   42973                9      1408         83 2024-11-04 2024-12-30

# %% [markdown]
# ## 📌 Feature Engineering [0.5 puntos]
#
# <center>
# <img src="https://i.imgur.com/CmXZSSC.gif" width="300" height="200">

# %% [markdown]
# En esta sección, se deben construir pipelines para automatizar el preprocesamiento de los datos, lo cual garantizará que el flujo de trabajo sea reproducible y eficiente para esta entrega y las futuras. El objetivo es aplicar una serie de transformaciones en un orden definido para asegurar que los datos estén listos para los modelos a entrenar. El pipeline final debe incluir las técnicas de pre-procesamiento que se deben aplicar a los distintos datos (según lo que consideren necesario para el problema). Por ejemplo:
#
# - **Imputación de valores nulos**: Manejo de datos faltantes mediante estrategias adecuadas (media, mediana, moda, interpolación, etc.).
#
# - **Transformaciones personalizadas**: Uso de ColumnTransformer para aplicar diferentes transformaciones a columnas específicas.
#
# - **Codificación de variables categóricas**: Convertir datos categóricos a un formato numérico adecuado (One-Hot Encoding, Label Encoding, etc.).
#
# - **Discretización de variables**: Conversión de variables numéricas continuas en categorías si son relevantes para el desempeño del modelo a entrenar.
#
# - **Estandarización o normalización** : Ajustar la escala de los datos para mejorar el rendimiento de los algoritmos sensibles a la magnitud de las variables.
#
# - **Eliminación o transformación de valores atípicos**: Identificar y tratar con datos outliers para mejorar la robustez del modelo.
#
# - **Nuevas características** : Creación de variables adicionales que puedan aportar información relevante al modelo.
#
# Cada una de estas transformaciones debe ser justificada en función de su relevancia para el problema y los datos, y es importante evaluar su impacto en el rendimiento del modelo. Además, el pipeline debe ser flexible y modular para poder probar diferentes configuraciones de preprocesamiento.

# %%
# FEATURE ENGINEERING
# Diseño:
# 1) Negativos: K por (cliente, semana) desde los TOP_P productos populares en TRAIN.
# 2) Features temporales: lags/recency y tasas previas (producto y cliente×categoría).
# 3) Preprocesamiento: imputación + OHE + escalado robusto en ColumnTransformer.
# 4) Salida: matrices X/y por split para entrenar el baseline.

SEED = 42
rng = np.random.default_rng(SEED)

WEEKLY_PATH  = "interacciones_semana.parquet"
HOLDOUT_PATH = "holdout_weeks.parquet"

# ---------------------------
# Carga y preparación base
# ---------------------------
weekly = pd.read_parquet(WEEKLY_PATH)
weeks_split = pd.read_parquet(HOLDOUT_PATH)

for df in (weekly, weeks_split):
    df.columns = [c.strip().lower() for c in df.columns]

weekly["customer_id"] = weekly["customer_id"].astype(str)
weekly["product_id"]  = weekly["product_id"].astype(str)
weekly["week"]        = pd.to_datetime(weekly["week"], errors="coerce")

weekly = weekly.merge(weeks_split, on="week", how="inner", validate="m:1")

weeks_sorted = np.sort(weekly["week"].unique())
week_to_idx  = pd.Series(np.arange(weeks_sorted.size), index=weeks_sorted)
weekly["week_idx"] = weekly["week"].map(week_to_idx).astype(int)

# ---------------------------
# Generación de NEGATIVOS
# ---------------------------
K_NEG = 5    # negativos por (cliente, semana)
TOP_P = 80   # pool de productos populares (definido solo con TRAIN)

pop_train = (weekly.query("split == 'train'")
                   .groupby("product_id", as_index=False)
                   .agg(cnt=("bought", "sum"))
                   .sort_values("cnt", ascending=False)
                   .head(TOP_P)["product_id"]
                   .to_numpy())

# Universo (cliente, semana, split)
cw = (weekly[["customer_id","week","split"]]
      .drop_duplicates()
      .sort_values(["week","customer_id"])
      .reset_index(drop=True))

# Muestreo vectorizado de productos
neg_prods = rng.choice(pop_train, size=len(cw)*K_NEG, replace=True)

neg_df = pd.DataFrame({
    "customer_id": np.repeat(cw["customer_id"].to_numpy(), K_NEG),
    "week":        np.repeat(cw["week"].to_numpy(), K_NEG),
    "split":       np.repeat(cw["split"].to_numpy(), K_NEG),
    "product_id":  neg_prods
})

# Anti-join contra positivos observados (para quitar falsos negativos)
pos_keys = weekly[["customer_id","week","product_id"]].drop_duplicates()
neg_df = (neg_df
          .merge(pos_keys, on=["customer_id","week","product_id"], how="left", indicator=True)
          .query("_merge == 'left_only'")
          .drop(columns="_merge"))

neg_df["bought"]   = 0
neg_df["week_idx"] = neg_df["week"].map(week_to_idx).astype(int)

# Unifica con positivos (solo columnas necesarias hasta aquí)
base = pd.concat([
    weekly[["customer_id","product_id","week","week_idx","split","bought"]],
    neg_df[["customer_id","product_id","week","week_idx","split","bought"]]
], ignore_index=True)

# Adjunta metadatos (categóricas/numéricas estáticas) de cliente y producto
meta_cols = ["customer_id","product_id","region_id","zone_id","customer_type",
             "y","x","num_deliver_per_week","num_visit_per_week",
             "brand","category","sub_category","segment","package","size_liters"]
meta = (weekly[meta_cols].drop_duplicates(subset=["customer_id","product_id"])
         .sort_values(["customer_id","product_id"]))
base = base.merge(meta, on=["customer_id","product_id"], how="left", validate="m:1")

# Orden temporal para lags/recency
base = base.sort_values(["customer_id","product_id","week_idx"]).reset_index(drop=True)

# ---------------------------
# FEATURES TEMPORALES
# ---------------------------
grp_cp = base.groupby(["customer_id","product_id"], sort=False)

# (a) Señal t-1: ¿compró ese SKU la semana anterior?
base["cp_prev_bought"] = grp_cp["bought"].shift(1).fillna(0).astype(np.float32)

# (b) Frecuencia en ventanas (4 y 12 semanas), excluyendo la semana actual
#     Usamos shift(1) y rolling por grupo; apply mantiene orden y evitamos loops.
base["cp_count_4w"]  = (grp_cp["bought"]
                        .apply(lambda s: s.shift(1).rolling(4,  min_periods=1).sum())
                        .reset_index(level=[0,1], drop=True)
                        .astype(np.float32))
base["cp_count_12w"] = (grp_cp["bought"]
                        .apply(lambda s: s.shift(1).rolling(12, min_periods=1).sum())
                        .reset_index(level=[0,1], drop=True)
                        .astype(np.float32))

# (c) Recency (semanas desde la última compra previa del mismo SKU por el cliente)
buy_idx = np.where(base["bought"].eq(1), base["week_idx"], -1_000_000)
last_buy_before = (pd.Series(buy_idx)
                   .groupby([base["customer_id"], base["product_id"]])
                   .cummax()
                   .shift(1)
                   .to_numpy())
base["cp_recency"] = (base["week_idx"] - last_buy_before).astype(np.float32)
base.loc[last_buy_before < 0, "cp_recency"] = 999.0

# (d) Popularidad previa del producto (tasa Beta-Bernoulli con suavizado)
grp_p = base.groupby("product_id", sort=False)
prior_buys = grp_p["bought"].cumsum().shift(1, fill_value=0.0)   # compras acumuladas hasta t-1
prior_obs  = grp_p.cumcount().astype(np.float32)                 # #observaciones hasta t-1
base["prod_prior_rate"] = ((prior_buys + 1.0) / (prior_obs + 2.0)).astype(np.float32)

# (e) Afinidad previa cliente×categoría (suavizado)
grp_cc = base.groupby(["customer_id","category"], sort=False)
cc_buys = grp_cc["bought"].cumsum().shift(1, fill_value=0.0)
cc_obs  = grp_cc.cumcount().astype(np.float32)
base["cust_cat_prior_rate"] = ((cc_buys + 1.0) / (cc_obs + 2.0)).astype(np.float32)

# ---------------------------
# Columnas y Pipeline de preprocesamiento
# ---------------------------
y = base["bought"].astype(int).to_numpy()

num_cols = [
    "cp_prev_bought","cp_count_4w","cp_count_12w","cp_recency",
    "prod_prior_rate","cust_cat_prior_rate",
    "size_liters","num_deliver_per_week","num_visit_per_week","y","x"
]
cat_cols = [
    "customer_type","region_id","zone_id",
    "brand","category","sub_category","segment","package"
]

preprocess = ColumnTransformer(
    transformers=[
        ("num", Pipeline([
            ("imp",   SimpleImputer(strategy="median")),
            ("scale", RobustScaler())
        ]), num_cols),
        ("cat", OneHotEncoder(handle_unknown="ignore", sparse_output=False), cat_cols),
    ],
    remainder="drop",
    verbose_feature_names_out=False
)

# ---------------------------
# Split y transformación (fit solo con TRAIN)
# ---------------------------
mask_train = base["split"].eq("train").to_numpy()
mask_valid = base["split"].eq("valid").to_numpy()
mask_test  = base["split"].eq("test").to_numpy()

X_train = base.loc[mask_train, num_cols + cat_cols]
y_train = y[mask_train]

X_valid = base.loc[mask_valid, num_cols + cat_cols]
y_valid = y[mask_valid]

X_test  = base.loc[mask_test,  num_cols + cat_cols]
y_test  = y[mask_test]

Xtr = preprocess.fit_transform(X_train)
Xva = preprocess.transform(X_valid)
Xte = preprocess.transform(X_test)

print("Shapes ->",
      "X_train:", Xtr.shape, "| X_valid:", Xva.shape, "| X_test:", Xte.shape)
print("Targets ->",
      "y_train:", y_train.shape, "| y_valid:", y_valid.shape, "| y_test:", y_test.shape)

# features resultantes
feature_names = preprocess.get_feature_names_out()
# Out:
# Shapes -> X_train: (263668, 59) | X_valid: (62018, 59) | X_test: (83738, 59)
# Targets -> y_train: (263668,) | y_valid: (62018,) | y_test: (83738,)

# %% [markdown]
# ## 📌 Baseline [0.25 puntos]
#
# <center>
# <img src="https://media1.giphy.com/media/v1.Y2lkPTc5MGI3NjExN3lzeGFqZmU3NzJrZHllNjRmaHVzczJpZ29rdHdlMzVpZnQwNXo1diZlcD12MV9pbnRlcm5hbF9naWZfYnlfaWQmY3Q9Zw/qAtZM2gvjWhPjmclZE/giphy.gif" width="300" height="200">

# %% [markdown]
# En esta sección se debe construir el modelo más sencillo posible que pueda resolver el problema planteado, conocido como **Modelo baseline**. Su propósito es servir como referencia para comparar el rendimiento de los modelos más avanzados desarrollados en etapas posteriores.
#
# Pasos requeridos:
# - Implemente, entrene y evalúe un modelo básico utilizando un pipeline.
# - Asegúrese de incluir en el pipeline las transformaciones del preprocesamiento realizadas previamente junto con un clasificador básico.
# - Evalúe el modelo y presente el informe de métricas utilizando **`classification_report`**.
#
# Documente claramente cómo se creó el modelo, las decisiones tomadas y los resultados obtenidos. Este modelo será la base comparativa en las secciones posteriores.

# %%
# BASELINE: Logistic Regression + pipeline
SEED = 42

# Pipeline = (preprocesamiento de Feature Engineering) + clasificador
baseline = Pipeline(steps=[
    ("prep", preprocess),  # imputación + OHE + escalado robusto
    ("clf", LogisticRegression(
        solver="saga",          # más robusto para OHE y mayor #features
        penalty="l2",
        C=1.0,
        max_iter=5000,
        tol=1e-4,
        class_weight="balanced",
        random_state=SEED
    ))
])

# Entrenamiento (solo TRAIN)
baseline.fit(X_train, y_train)

# Evaluación en VALID: probabilidades + métricas globales + umbral F1
p_valid = baseline.predict_proba(X_valid)[:, 1]
auc_valid = roc_auc_score(y_valid, p_valid)
ap_valid  = average_precision_score(y_valid, p_valid)

# Umbral óptimo por F1 (vectorizado sobre la curva P-R)
prec, rec, thr = precision_recall_curve(y_valid, p_valid)
f1 = (2 * prec * rec) / (prec + rec + 1e-12)  # evita división por cero
best_idx = np.nanargmax(f1[:-1])              # len(thr) = len(prec)-1
best_thr = thr[best_idx]

yhat_valid_05  = (p_valid >= 0.5).astype(int)
yhat_valid_opt = (p_valid >= best_thr).astype(int)

print("=== VALID ===")
print(f"AUC-ROC: {auc_valid:.4f} | PR-AUC: {ap_valid:.4f}")
print(f"Umbral óptimo (F1): {best_thr:.4f}\n")
print("Classification report (threshold = 0.5):")
print(classification_report(y_valid, yhat_valid_05, digits=4))
print("\nClassification report (threshold óptimo por F1):")
print(classification_report(y_valid, yhat_valid_opt, digits=4))

# Evaluación en TEST con el umbral fijado en VALID
p_test = baseline.predict_proba(X_test)[:, 1]
auc_test = roc_auc_score(y_test, p_test)
ap_test  = average_precision_score(y_test, p_test)
yhat_test_opt = (p_test >= best_thr).astype(int)

print("\n=== TEST (umbral de VALID) ===")
print(f"AUC-ROC: {auc_test:.4f} | PR-AUC: {ap_test:.4f}\n")
print("Classification report (threshold óptimo):")
print(classification_report(y_test, yhat_test_opt, digits=4))

# Matrices de confusión
cm_valid = confusion_matrix(y_valid, yhat_valid_opt)
cm_test  = confusion_matrix(y_test,  yhat_test_opt)
print("\nMatriz de confusión VALID:\n", cm_valid)
print("\nMatriz de confusión TEST:\n", cm_test)
# Out:
# === VALID ===
# AUC-ROC: 0.9518 | PR-AUC: 0.9378
# Umbral óptimo (F1): 0.5198
#
# Classification report (threshold = 0.5):
#               precision    recall  f1-score   support
#
#            0     1.0000    0.7753    0.8734     31316
#            1     0.8136    1.0000    0.8972     30702
#
#     accuracy                         0.8865     62018
#    macro avg     0.9068    0.8877    0.8853     62018
# weighted avg     0.9077    0.8865    0.8852     62018
#
#
# Classification report (threshold óptimo por F1):
#               precision    recall  f1-score   support
#
#            0     1.0000    0.7753    0.8734     31316
#            1     0.8136    1.0000    0.8972     30702
#
#     accuracy                         0.8865     62018
#    macro avg     0.9068    0.8877    0.8853     62018
# weighted avg     0.9077    0.8865    0.8852     62018
#
#
# === TEST (umbral de VALID) ===
# AUC-ROC: 0.9483 | PR-AUC: 0.9361
#
# Classification report (threshold óptimo):
# ...

# %% [markdown]
# ## 📌 Elección de modelo [0.75 puntos]
#
# En esta sección deben escoger un modelo que se adapte a las necesidades del negocio. Para esto, pruebe al menos 3 modelos y desarrolle los siguientes aspectos para cada uno:
#
# - **Estructura y diferencias entre los modelos**: Explicar brevemente cada uno y sus hipérparámetros de mayor importancia.
# - **Clasificadores recomendados**:
#   - `LogisticRegression`
#   - `KNeighborsClassifier`
#   - `DecisionTreeClassifier`
#   - `SVC`
#   - `RandomForestClassifier`
#   - `LightGBMClassifier` (del paquete `lightgbm`)
#   - `XGBClassifier` (del paquete `xgboost`)
#   - Otro (según lo que se estime adecuado)
#
# - **Evaluación de resultados**: Se utilizará el **`classification_report`** para evaluar el rendimiento de cada modelo, destacando métricas clave como precisión, recall y F1-score. **Importante: No optimicen hiperparámetros, la idea es hacer una selección rápida del modelo.**
#
# **Nota:** Pueden ocupar mas de 1 **instancia** de modelo para resolver el problema (e.g: (modelo_1, grupo_1), (modelo_2, grupo_2), ...).
#
# A continuación, se deben responder las siguientes preguntas para evaluar el rendimiento de los modelos entrenados:
#
# 1. ¿Hay algún clasificador que supere al modelo baseline?
# 2. ¿Cuál es el mejor clasificador entrenado y por qué?
# 3. ¿Qué factores hacen que el mejor clasificador sea superior a los otros?
# 4. En términos de `tiempo de entrenamiento`, ¿Qué modelo considera más adecuado para experimentar con grillas de optimización?

# %%
# ELECCIÓN DE MODELO
SEED = 42

# ---------------------------
# Definición de modelos candidatos
#    Elegimos 3 bien contrastantes y eficientes con OHE:
#    - LogReg: lineal, baseline.
#    - RandomForest: no lineal, ensamble de árboles.
#    - HistGradientBoosting: boosting eficiente en grandes datasets.
# ---------------------------
candidatos = []

# LogReg (mismo espíritu del baseline, solver robusto)
candidatos.append((
    "LogisticRegression",
    LogisticRegression(solver="saga", penalty="l2",
                       class_weight="balanced",
                       max_iter=5000, tol=1e-4, random_state=SEED)
))

# RandomForest (valores por defecto razonables)
candidatos.append((
    "RandomForest",
    RandomForestClassifier(
        n_estimators=300,        # tamaño moderado del bosque
        max_depth=None,
        n_jobs=-1,
        class_weight="balanced_subsample",
        random_state=SEED
    )
))

# HistGradientBoosting (rápido y fuerte sin demasiados parámetros)
candidatos.append((
    "HistGradientBoosting",
    HistGradientBoostingClassifier(
        loss="log_loss",
        max_depth=None,
        learning_rate=0.1,
        max_iter=200,           # iteraciones moderadas
        random_state=SEED
    )
))

# XGBoost/LightGBM
try:
    from xgboost import XGBClassifier
    candidatos.append((
        "XGBClassifier",
        XGBClassifier(
            n_estimators=300, learning_rate=0.1, max_depth=6,
            subsample=0.8, colsample_bytree=0.8,
            reg_lambda=1.0, objective="binary:logistic",
            eval_metric="aucpr", tree_method="hist",
            random_state=SEED
        )
    ))
except Exception:
    pass

try:
    from lightgbm import LGBMClassifier
    candidatos.append((
        "LGBMClassifier",
        LGBMClassifier(
            n_estimators=500, learning_rate=0.05, num_leaves=63,
            subsample=0.8, colsample_bytree=0.8,
            class_weight="balanced", random_state=SEED
        )
    ))
except Exception:
    pass

# ---------------------------
# Función de entrenamiento+evaluación coherente con el baseline
#    - Se ajusta pipeline (preprocess + clf) en TRAIN
#    - Se elige umbral en VALID maximizando F1 (P-R)
#    - Se evalúa VALID y TEST con ese umbral
# ---------------------------
def _fit_eval(nombre_modelo, clf):
    pipe = Pipeline([("prep", preprocess), ("clf", clf)])

    t0 = time.perf_counter()
    pipe.fit(X_train, y_train)
    train_s = time.perf_counter() - t0

    # Probs VALID/TEST
    p_valid = pipe.predict_proba(X_valid)[:, 1]
    p_test  = pipe.predict_proba(X_test)[:, 1]

    # AUC y PR-AUC
    auc_v = roc_auc_score(y_valid, p_valid)
    pr_v  = average_precision_score(y_valid, p_valid)
    auc_t = roc_auc_score(y_test,  p_test)
    pr_t  = average_precision_score(y_test,  p_test)

    # Umbral óptimo por F1 en VALID
    prec, rec, thr = precision_recall_curve(y_valid, p_valid)
    f1 = (2 * prec * rec) / (prec + rec + 1e-12)
    best_idx = np.nanargmax(f1[:-1])
    best_thr = float(thr[best_idx])

    # Reportes de clasificación (VALID y TEST con ese umbral)
    yhat_v = (p_valid >= best_thr).astype(int)
    yhat_t = (p_test  >= best_thr).astype(int)

    rep_valid = classification_report(y_valid, yhat_v, digits=4)
    rep_test  = classification_report(y_test,  yhat_t, digits=4)

    # Métricas resumidas para tabla comparativa
    # Tomamos valores en el punto de F1 óptimo (aproximamos con arrays prec/rec)
    prec_best, rec_best, f1_best = float(prec[best_idx]), float(rec[best_idx]), float(f1[best_idx])

    return {
        "modelo": nombre_modelo,
        "train_seg": train_s,
        "auc_valid": auc_v, "pr_valid": pr_v,
        "thr_f1_valid": best_thr,
        "prec_valid": prec_best, "rec_valid": rec_best, "f1_valid": f1_best,
        "auc_test": auc_t, "pr_test": pr_t,
        "rep_valid": rep_valid, "rep_test": rep_test
    }

# ---------------------------
# Entrenamiento y evaluación de todos los candidatos
# ---------------------------
resultados = list(map(lambda par: _fit_eval(par[0], par[1]), candidatos))

# Tabla resumen ordenada por PR-AUC VALID y luego F1 VALID
tabla = (pd.DataFrame(resultados)
         .sort_values(["pr_valid", "f1_valid"], ascending=False)
         .reset_index(drop=True)
         .loc[:, ["modelo","train_seg","auc_valid","pr_valid","f1_valid",
                  "auc_test","pr_test","thr_f1_valid"]])

print("=== RESUMEN COMPARATIVO (ordenado por PR-AUC VALID) ===")
print(tabla.to_string(index=False))

# Mostrar reports completos para cada modelo (VALID y TEST)
_ = list(map(lambda r: (
    print("\n\n===================="),
    print(f"Modelo: {r['modelo']}"),
    print("-------------------- VALID (umbral F1) --------------------"),
    print(r["rep_valid"]),
    print("-------------------- TEST  (umbral F1) --------------------"),
    print(r["rep_test"])
), resultados))
# Out:
# [LightGBM] [Info] Number of positive: 124553, number of negative: 139115
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.018690 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1228
# [LightGBM] [Info] Number of data points in the train set: 263668, number of used features: 55
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=-0.000000
# [LightGBM] [Info] Start training from score -0.000000
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# ...

# %% [markdown]
# ### Respuestas a las preguntas
#
# 1. **¿Hay algún clasificador que supere al modelo baseline?**
#    Sí. Los tres *boosters* (LGBMClassifier, HistGradientBoosting, XGBClassifier) y también RandomForest superan a LogisticRegression en PR-AUC y F1 en VALID. En la tabla:
#    LGBM (PR-AUC VALID = 0.9613) ≈ HGB (0.9612) > XGB (0.9608) > RF (0.9560) >> LR (0.9378).
#
# 2. **¿Cuál es el mejor clasificador entrenado y por qué?**
#    LGBMClassifier. Presenta la mejor PR-AUC en VALID (0.9613), mantiene o mejora en TEST (PR-AUC 0.9641) y fue rápido de entrenar (~15.5 s). El desempeño es virtualmente empatado con HistGradientBoosting y XGBClassifier, pero LGBM tiene ligera ventaja y excelente tiempo/eficiencia.
#
# 3. **¿Qué factores hacen que el mejor clasificador sea superior a los otros?**
#
# * Modela no linealidades e interacciones entre lags/recency y atributos (cliente/producto) que la regresión logística no captura.
# * Maneja bien alto número de variables OHE (sparse/dense), con regularización efectiva y construcción de árboles eficientes.
# * Mejor compromiso sesgo–varianza: extrae señal fina sin sobreajustar (VALID ≈ TEST).
# * Eficiencia computacional: con parámetros por defecto ya logra un rendimiento top.
#
# 4. **En tiempo de entrenamiento, ¿qué modelo es más adecuado para grillas de optimización?**
#    LGBMClassifier (y XGBClassifier si está disponible) por su velocidad y estabilidad. HistGradientBoosting también es una gran opción. RandomForest fue significativamente más lento (~128 s) y LogisticRegression resultó el más lento (~2072 s) debido al tamaño y a la OHE densa, por lo que no es la mejor opción para *grids* amplias aquí.

# %%
# CHECKPOINT (preprocesador + modelo ganador + umbral + metadatos)

# Nota: reentrenamos solo el modelo ganador (LGBM) sobre Xtr, elegimos umbral en VALID
# y persistimos todo en 'artifacts/'. Evitamos re-ajustar el preprocesador.

ART = Path("artifacts"); ART.mkdir(exist_ok=True)

# Guardar el preprocesador ya ajustado
dump(preprocess, ART / "preprocess_v1.joblib", compress=3)

# Entrenar y guardar el modelo ganador (LGBM) sobre matrices ya transformadas
SEED = 42
lgbm = LGBMClassifier(
    n_estimators=500, learning_rate=0.05, num_leaves=63,
    subsample=0.8, colsample_bytree=0.8,
    class_weight="balanced", random_state=SEED
)
lgbm.fit(Xtr, y_train)

# Umbral óptimo (F1) en VALID
p_valid = lgbm.predict_proba(Xva)[:, 1]
prec, rec, thr = precision_recall_curve(y_valid, p_valid)
f1 = (2 * prec * rec) / (prec + rec + 1e-12)
best_idx = np.nanargmax(f1[:-1])
best_thr = float(thr[best_idx])

# Métricas (para metadata)
metrics = {
    "valid": {
        "auc_roc": float(roc_auc_score(y_valid, p_valid)),
        "pr_auc": float(average_precision_score(y_valid, p_valid)),
        "thr_f1": best_thr
    },
    "test": {
        "auc_roc": float(roc_auc_score(y_test, lgbm.predict_proba(Xte)[:, 1])),
        "pr_auc": float(average_precision_score(y_test, lgbm.predict_proba(Xte)[:, 1]))
    }
}

# Guardar el modelo y metadatos
dump(lgbm, ART / "model_lgbm_v1.joblib", compress=3)

meta = {
    "created_at": datetime.utcnow().isoformat(timespec="seconds") + "Z",
    "python": platform.python_version(),
    "sklearn": sklearn.__version__,
    "artifact_paths": {
        "preprocess": "preprocess_v1.joblib",
        "model": "model_lgbm_v1.joblib"
    },
    "threshold_f1_valid": best_thr,
    "metrics": metrics,
    "notes": "Checkpoint post 'Elección de modelo' (sin tuning). Holdout temporal purgado, umbral en VALID."
}
with open(ART / "metadata_lgbm_v1.json", "w") as f:
    json.dump(meta, f, indent=2)

# Guardar matrices transformadas para acelerar experimentos futuros
np.savez_compressed(ART / "matrix_cache_v1.npz",
                    Xtr=Xtr, y_train=y_train,
                    Xva=Xva, y_valid=y_valid,
                    Xte=Xte, y_test=y_test,
                    feature_names=np.array(feature_names, dtype=object))
print("Artefactos guardados en ./artifacts/")
# Out:
# [LightGBM] [Info] Number of positive: 124553, number of negative: 139115
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.031332 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1228
# [LightGBM] [Info] Number of data points in the train set: 263668, number of used features: 55
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=-0.000000
# [LightGBM] [Info] Start training from score -0.000000
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# ...

# %% [markdown]
# ## 📌 Optimización de Hiperparámetros [1.0 puntos]
#
# <center>
# <img src="https://media1.giphy.com/media/v1.Y2lkPTc5MGI3NjExcXJkNzdhYjlneHplaGpsbnVkdzh5dnY3Y2VyaTIzamszdGR1czJ2diZlcD12MV9pbnRlcm5hbF9naWZfYnlfaWQmY3Q9Zw/2rqEdFfkMzXmo/giphy.gif" width="300" height="200">

# %% [markdown]
# A partir de su análisis anterior, se debe proceder a optimizar el rendimiento del modelo seleccionado mediante la optimización de sus hiperparámetros. Para ello, se espera que implementen `Optuna` para optimizar no solo los hiperparámetros del modelo, sino también los de los preprocesadores utilizados (por ejemplo, OneHot Encoding, Scalers, etc.).
#
# Al desarrollar este proceso, deberán responder las siguientes preguntas clave como mínimo:
#
# - ¿Qué métrica decidieron optimizar y por qué?
#
# - ¿Qué hiperparámetro tuvo un mayor impacto en el rendimiento de su modelo?
#
# - ¿Cuánto mejoró el rendimiento del modelo después de la optimización de hiperparámetros?

# %%
# OPTIMIZACIÓN DE HIPERPARÁMETROS

# Nota: en cada trial se recompone y ajusta un preprocesador (imputación+OHE+scaler),
#       y luego se entrena un LGBMClassifier con early-stopping. El objetivo maximiza PR-AUC en VALID.

SEED = 42
rng = np.random.default_rng(SEED)

# Columnas numéricas y categóricas
try:
    num_cols, cat_cols
except NameError:
    num_cols = X_train.select_dtypes(include=[np.number]).columns.tolist()
    cat_cols = [c for c in X_train.columns if c not in num_cols]

# Utilidades para armar preprocesamiento por trial
def _make_ohe(min_freq):
    # Maneja compatibilidad de scikit-learn con/ sin min_frequency y sparse_output
    try:
        return OneHotEncoder(handle_unknown="ignore", sparse_output=False, min_frequency=min_freq)
    except TypeError:
        try:
            return OneHotEncoder(handle_unknown="ignore", sparse=False)
        except TypeError:
            # fallback ultra-conservador
            return OneHotEncoder(handle_unknown="ignore")

def build_preprocess(trial):
    # Imputación numérica
    num_imp_strategy = trial.suggest_categorical("num_imputer", ["median","mean"])
    num_imputer = SimpleImputer(strategy=num_imp_strategy)

    # Escalado numérico (o no)
    scaler_choice = trial.suggest_categorical("num_scaler", ["robust","standard","none"])
    if scaler_choice == "robust":
        num_scaler = RobustScaler()
    elif scaler_choice == "standard":
        num_scaler = StandardScaler()
    else:
        num_scaler = "passthrough"

    # Rarefacción de categorías poco frecuentes en OHE (permite compactar cardinalidades)
    drop_rare = trial.suggest_categorical("ohe_drop_rare", [True, False])
    min_freq = trial.suggest_float("ohe_min_freq", 0.001, 0.01) if drop_rare else None
    ohe = _make_ohe(min_freq)

    num_pipe = Pipeline([("imp", num_imputer), ("scaler", num_scaler)])
    pre = ColumnTransformer(
        transformers=[
            ("num", num_pipe, num_cols),
            ("cat", ohe, cat_cols),
        ],
        remainder="drop",
        verbose_feature_names_out=False
    )
    return pre

# Espacio de búsqueda del modelo (LGBM)
def suggest_lgbm(trial):
    params = dict(
        n_estimators = trial.suggest_int("n_estimators", 300, 2000),
        learning_rate = trial.suggest_float("learning_rate", 1e-2, 2e-1, log=True),
        num_leaves = trial.suggest_int("num_leaves", 31, 255),
        max_depth = trial.suggest_categorical("max_depth", [-1, 6, 8, 10, 12]),
        min_child_samples = trial.suggest_int("min_child_samples", 10, 200),
        subsample = trial.suggest_float("subsample", 0.5, 1.0),
        colsample_bytree = trial.suggest_float("colsample_bytree", 0.5, 1.0),
        reg_alpha = trial.suggest_float("reg_alpha", 0.0, 2.0),
        reg_lambda = trial.suggest_float("reg_lambda", 0.0, 5.0),
        class_weight = "balanced",
        random_state = SEED,
        n_jobs = -1
    )
    return params

# Función objetivo de Optuna (maximiza PR-AUC en VALID)
def objective(trial):
    pre = build_preprocess(trial)
    # Ajusta preprocesador con TRAIN y transforma TRAIN/VALID
    Xtr = pre.fit_transform(X_train, y_train)
    Xva = pre.transform(X_valid)

    # Modelo y early-stopping (validación en VALID)
    lgbm = LGBMClassifier(**suggest_lgbm(trial))
    lgbm.fit(
        Xtr, y_train,
        eval_set=[(Xva, y_valid)],
        eval_metric="auc",                  # estable; PR-AUC la medimos con sklearn
        callbacks=[early_stopping(50, verbose=False), log_evaluation(0)]
    )

    # Métrica objetivo: PR-AUC en VALID
    p_valid = lgbm.predict_proba(Xva)[:, 1]
    pr_valid = average_precision_score(y_valid, p_valid)

    # Pruning opcional si el desempeño es débil
    trial.report(pr_valid, step=0)
    if trial.should_prune():
        raise optuna.TrialPruned()

    return pr_valid

# Lanzar la búsqueda
N_TRIALS = 30            # puedes ajustar según presupuesto de cómputo
study = optuna.create_study(direction="maximize",
                            sampler=TPESampler(seed=SEED),
                            pruner=MedianPruner(n_warmup_steps=5))
study.optimize(objective, n_trials=N_TRIALS, show_progress_bar=False)

print("Mejor PR-AUC VALID:", study.best_value)
print("Mejores hiperparámetros:", study.best_trial.params)

# Reentrenar con el mejor trial y evaluar (VALID/TEST)
best_params = study.best_trial.params
best_pre = build_preprocess(study.best_trial)
Xtr_best = best_pre.fit_transform(X_train, y_train)
Xva_best = best_pre.transform(X_valid)
Xte_best = best_pre.transform(X_test)

best_lgbm = LGBMClassifier(**suggest_lgbm(study.best_trial))
best_lgbm.fit(
    Xtr_best, y_train,
    eval_set=[(Xva_best, y_valid)],
    eval_metric="auc",
    callbacks=[early_stopping(50, verbose=False), log_evaluation(0)]
)

# Probabilidades y métricas
p_valid = best_lgbm.predict_proba(Xva_best)[:, 1]
p_test  = best_lgbm.predict_proba(Xte_best)[:, 1]

auc_v = roc_auc_score(y_valid, p_valid)
pr_v  = average_precision_score(y_valid, p_valid)
auc_t = roc_auc_score(y_test,  p_test)
pr_t  = average_precision_score(y_test,  p_test)

# Umbral óptimo por F1 en VALID y reports
prec, rec, thr = precision_recall_curve(y_valid, p_valid)
f1 = (2 * prec * rec) / (prec + rec + 1e-12)
best_idx = np.nanargmax(f1[:-1])
thr_f1 = float(thr[best_idx])

yhat_v = (p_valid >= thr_f1).astype(int)
yhat_t = (p_test  >= thr_f1).astype(int)

print("\n=== RESUMEN ÓPTIMO ===")
print(f"VALID -> AUC: {auc_v:.6f} | PR-AUC: {pr_v:.6f} | thr(F1): {thr_f1:.4f}")
print(f"TEST  -> AUC: {auc_t:.6f} | PR-AUC: {pr_t:.6f}")

print("\n--- Classification report (VALID, thr F1) ---")
print(classification_report(y_valid, yhat_v, digits=4))
print("\n--- Classification report (TEST, thr F1 de VALID) ---")
print(classification_report(y_test, yhat_t, digits=4))

# Persistir artefactos del mejor trial para continuar sin reejecutar todo
os.makedirs("artifacts_optuna", exist_ok=True)
dump(best_pre, "artifacts_optuna/preprocess_best.joblib", compress=3)
dump(best_lgbm, "artifacts_optuna/model_lgbm_best.joblib", compress=3)
with open("artifacts_optuna/metadata.json","w") as f:
    json.dump({
        "study_best_value_pr_auc_valid": float(study.best_value),
        "best_params": best_params,
        "threshold_f1_valid": thr_f1,
        "metrics": {
            "valid": {"auc": float(auc_v), "pr_auc": float(pr_v)},
            "test" : {"auc": float(auc_t), "pr_auc": float(pr_t)}
        }
    }, f, indent=2)
print("\nArtefactos guardados en ./artifacts_optuna/")
# Out:
# [I 2025-10-07 22:21:34,966] A new study created in memory with name: no-name-722f3b91-2bae-4cbe-ba15-66fe70070783
# [LightGBM] [Info] Number of positive: 124553, number of negative: 139115
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.037744 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1183
# [LightGBM] [Info] Number of data points in the train set: 263668, number of used features: 43
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=-0.000000
# [LightGBM] [Info] Start training from score -0.000000
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# ...

# %% [markdown]
# ### Respuestas a las preguntas
#
# 1. **¿Qué métrica decidieron optimizar y por qué?**
#
# PR-AUC en VALID. En un problema desbalanceado de compra/no compra semanal, PR-AUC resume mejor la calidad de la clase positiva (compras) y se correlaciona con indicadores operativos como *Precision@K*/*Recall@K* por cliente-semana para priorizar ofertas del portafolio. Por eso la usamos como objetivo de Optuna y mantenemos AUC-ROC como métrica de control.
#
# 2. **¿Qué hiperparámetro tuvo mayor impacto?**
#
# Del `metadata.json` del *best trial* se observa el patrón de mejora en *boosting*:
#
# * Capacidad/forma del árbol:
#   `num_leaves = 110`, `max_depth = 12` y `min_child_samples = 120`.
#   Más hojas y profundidad permiten capturar no linealidades e interacciones complejas; el `min_child_samples` alto evita sobreajuste.
# * Capacidad global y regularización:
#   `learning_rate ≈ 0.04` con `n_estimators = 1643` (más iteraciones a menor *lr*) mejoran el ajuste fino;
#   `subsample ≈ 0.66` y `colsample_bytree ≈ 0.78` añaden diversidad;
#   `reg_alpha ≈ 1.77` y `reg_lambda ≈ 0.21` controlan complejidad.
# * Preprocesamiento:
#   Rarefacción en OHE (`ohe_drop_rare = true`, `ohe_min_freq ≈ 0.006`) agrupa categorías escasas, reduce ruido y estabiliza la señal categórica; `num_scaler = robust` y `num_imputer = mean` fueron seleccionados, con efecto menor en *boosters* pero útiles en presencia de outliers.
#
# En conjunto, la dupla (*capacidad del árbol* + *capacidad global/regularización*) explica la mayor parte de la ganancia; la rarefacción de OHE aporta estabilidad adicional.
#
# 3. **¿Cuánto mejoró el rendimiento tras la optimización?**
#
# Comparado con la selección sin *tuning* (tu “Elección de modelo”, LGBM por defecto):
#
# * PR-AUC VALID: 0.96126 → 0.96196 (≈ +0.07 pp).
# * PR-AUC TEST : 0.96412 → 0.96528 (≈ +0.12 pp).
# * F1 (clase 1): sube ≈ +0.2 pp en VALID y ≈ +0.5 pp en TEST (con el umbral F1 elegido en VALID).

# %% [markdown]
# ## 📌 Interpretabilidad [1.0 puntos]
#
# En esta sección, deben explicar el funcionamiento de su modelo utilizando las técnicas de interpretabilidad vistas en clase, como `SHAP`. Se espera que sean capaces de descomponer las predicciones y evaluar la importancia de los atributos y las interacciones entre ellos, con el fin de obtener una comprensión más profunda de cómo el modelo toma decisiones.
#
# Al desarrollar esta parte, deberán responder las siguientes preguntas clave como mínimo:
#
# - ¿Podría explicar el funcionamiento de su modelo para una predicción en particular? Si es así, proporcione al menos tres ejemplos específicos, describiendo cómo el modelo llegó a sus decisiones y qué factores fueron más relevantes en cada caso.
#
# - ¿Qué atributo tiene una mayor importancia en la salida de su modelo? Analice si esto tiene sentido con el problema planteado y justifique la relevancia de dicho atributo en el contexto de las predicciones que se realizan.
#
# - ¿Existe alguna interacción entre atributos que sea relevante para el modelo? Investigue si la combinación de ciertos atributos tiene un impacto significativo en las predicciones y explíquela en **detalle**.
#
# - ¿Podría existir sesgo hacia algún atributo en particular? Reflexione sobre la posibilidad de que el modelo esté favoreciendo ciertos atributos. Si es así, ¿cuál podría ser la causa y qué impacto podría tener esto en la predicción?

# %%
# INTERPRETABILIDAD
# - Carga preprocesador/modelo óptimos + umbral F1 VALID
# - SHAP global (beeswarm + bar) y dependencias (3 features top)
# - Interacciones SHAP (top pares)
# - Explicaciones locales (3 casos: alto, borde, bajo)
# - Chequeo de sesgo por categorías OHE (customer_type, region_id)

# -----------------------------
# Carga de artefactos + data
# -----------------------------
ART = Path("artifacts_optuna")
preprocess_best = load(ART / "preprocess_best.joblib")
model_lgbm_best = load(ART / "model_lgbm_best.joblib")
meta = json.loads((ART / "metadata.json").read_text())
thr_f1 = float(meta["threshold_f1_valid"])

# Transformaciones consistentes con entrenamiento óptimo
Xva_best = preprocess_best.transform(X_valid)
Xte_best = preprocess_best.transform(X_test)

# Nombres de variables post-ColumnTransformer/OHE
try:
    feature_names = preprocess_best.get_feature_names_out()
except Exception:
    feature_names = np.array([f"f_{i}" for i in range(Xva_best.shape[1])], dtype=object)

# -----------------------------
# SHAP: explicador y valores
# -----------------------------
# Para modelos de árboles, TreeExplainer es eficiente.
expl = shap.TreeExplainer(model_lgbm_best)

# Para binario, versiones recientes devuelven lista [negativo, positivo]
shap_values_valid = expl.shap_values(Xva_best, check_additivity=False)
if isinstance(shap_values_valid, list):
    shap_values_valid = shap_values_valid[1]

expected_value = expl.expected_value[1] if np.ndim(expl.expected_value) > 0 else expl.expected_value

# -----------------------------
# Importancia global
# -----------------------------
plt.figure(figsize=(9,6))
shap.summary_plot(shap_values_valid, Xva_best, feature_names=feature_names, show=True)

plt.figure(figsize=(9,6))
shap.summary_plot(shap_values_valid, Xva_best, feature_names=feature_names,
                  plot_type="bar", show=True)

# Tabla de ranking global por |SHAP| promedio
mean_abs_shap = np.mean(np.abs(shap_values_valid), axis=0)
imp_table = (pd.DataFrame({"feature": feature_names, "mean_abs_shap": mean_abs_shap})
               .sort_values("mean_abs_shap", ascending=False)
               .reset_index(drop=True))
print("=== TOP-15 FEATURES POR |SHAP| PROMEDIO (VALID) ===")
display(imp_table.head(15))

# -----------------------------
# Dependencias e interacciones
# -----------------------------
# Top-3
top3 = imp_table["feature"].values[:3]

plt.figure(figsize=(7,5))
shap.dependence_plot(top3[0], shap_values_valid, Xva_best, feature_names=feature_names,
                     interaction_index="auto", show=True)

plt.figure(figsize=(7,5))
shap.dependence_plot(top3[1], shap_values_valid, Xva_best, feature_names=feature_names,
                     interaction_index="auto", show=True)

plt.figure(figsize=(7,5))
shap.dependence_plot(top3[2], shap_values_valid, Xva_best, feature_names=feature_names,
                     interaction_index="auto", show=True)

# Interacciones SHAP sobre una muestra
try:
    n_samp = min(2000, Xva_best.shape[0])
    rng = np.random.default_rng(42)
    idx_samp = rng.choice(Xva_best.shape[0], size=n_samp, replace=False)

    SI = expl.shap_interaction_values(Xva_best[idx_samp])
    if isinstance(SI, list):
        SI = SI[1]   # clase positiva

    S = np.mean(np.abs(SI), axis=0)              # (p,p)
    iu = np.triu_indices_from(S, k=1)
    order = np.argsort(S[iu])[::-1][:15]
    pairs = np.stack([iu[0][order], iu[1][order]], axis=1)
    top_pairs_df = pd.DataFrame({
        "feat_i": feature_names[pairs[:,0]],
        "feat_j": feature_names[pairs[:,1]],
        "mean_abs_interaction": S[iu][order]
    })
    print("=== TOP-15 INTERACCIONES (mean |SHAP_interaction|, VALID-sample) ===")
    display(top_pairs_df)
except Exception as e:
    print("[AVISO] Interacciones SHAP no disponibles en esta versión/entorno:", e)

# -----------------------------
# Explicaciones locales (3 casos)
# -----------------------------
p_valid = model_lgbm_best.predict_proba(Xva_best)[:, 1]
idx_high = int(np.argmax(p_valid))                         # más alta
idx_mid  = int(np.argmin(np.abs(p_valid - thr_f1)))        # cerca del umbral F1
idx_low  = int(np.argmin(p_valid))                         # más baja

sv_high = shap_values_valid[idx_high]
sv_mid  = shap_values_valid[idx_mid]
sv_low  = shap_values_valid[idx_low]

# Mostramos force plots
shap.initjs()
print("\n=== CASO A (probabilidad alta) — force plot ===")
display(shap.force_plot(expected_value, sv_high, feature_names=feature_names))
print("\n=== CASO B (cerca del umbral F1) — force plot ===")
display(shap.force_plot(expected_value, sv_mid,  feature_names=feature_names))
print("\n=== CASO C (probabilidad baja) — force plot ===")
display(shap.force_plot(expected_value, sv_low,  feature_names=feature_names))

# Tablas TOP-10 contribuciones por caso
def top_contrib_row(sv_row, k=10):
    ord_idx = np.argsort(np.abs(sv_row))[::-1][:k]
    return pd.DataFrame({
        "feature": feature_names[ord_idx],
        "shap_value": sv_row[ord_idx],
        "abs_shap": np.abs(sv_row[ord_idx])
    })

print("\n=== CASO A — TOP-10 contribuciones ===")
display(top_contrib_row(sv_high, 10))
print("\n=== CASO B — TOP-10 contribuciones ===")
display(top_contrib_row(sv_mid, 10))
print("\n=== CASO C — TOP-10 contribuciones ===")
display(top_contrib_row(sv_low, 10))

# -----------------------------
# Chequeo de sesgos por categorías OHE
# -----------------------------
def shap_group_by_prefix(prefix, shap_matrix, feat_names, top=10):
    s = pd.Series(feat_names, dtype=str)
    mask = s.str.startswith(prefix + "_").values
    if not mask.any():
        return pd.DataFrame(columns=["category","mean_abs_shap"])
    cats = s[mask].str.split(prefix + "_", n=1, expand=True)[1].values
    df_abs = pd.DataFrame(np.abs(shap_matrix[:, mask]), columns=cats)
    out = df_abs.mean(axis=0).sort_values(ascending=False).head(top).rename_axis("category").reset_index(name="mean_abs_shap")
    return out

print("\n=== SHAP medio por categoría — customer_type (TOP-10) ===")
display(shap_group_by_prefix("customer_type", shap_values_valid, feature_names, top=10))

print("\n=== SHAP medio por categoría — region_id (TOP-10) ===")
display(shap_group_by_prefix("region_id", shap_values_valid, feature_names, top=10))
# Out:
# /usr/local/lib/python3.12/dist-packages/shap/explainers/_tree.py:583: UserWarning: LightGBM binary classifier with TreeExplainer shap values output has changed to a list of ndarray
#   warnings.warn(
# === TOP-15 FEATURES POR |SHAP| PROMEDIO (VALID) ===
#                     feature  mean_abs_shap
# 0         customer_type_nan       3.613761
# 1              region_id_80       1.145403
# 2                cp_recency       0.456823
# 3           prod_prior_rate       0.272454
# 4             region_id_nan       0.265064
# 5            cp_prev_bought       0.135167
# 6              cp_count_12w       0.129757
# 7               cp_count_4w       0.113387
# 8              zone_id_5148       0.105365
# 9       cust_cat_prior_rate       0.062131
# 10              size_liters       0.053336
# 11           brand_BRAND 34       0.045194
# 12                        x       0.033987
# 13              zone_id_nan       0.032872
# 14  customer_type_ABARROTES       0.031513
# ...

# %% [markdown]
# ### Respuestas a las preguntas
#
# 1. **Explicación del modelo en 3 predicciones concretas (casos A/B/C)**
#
#    Usando los TOP-10 SHAP por observación:
#
#    **Caso A – probabilidad alta**
#    Contribuciones principales (todas positivas salvo indicación):
#    `customer_type_nan` +3.66, `region_id_80` +1.16, `cp_recency` +0.71, `prod_prior_rate` +0.70, `cp_count_12w` +0.35.
#    Lectura: el modelo empuja con fuerza hacia “compra”. El cliente con tipo no informado (`customer_type_nan=1`) y estar en región 80 elevan el *logit*. Además, la recencia cliente-producto favorable y una tasa previa de compra alta refuerzan la señal (historial y hábito). La acumulación de compras en 12 semanas suma coherentemente. Es una combinación clásica: historial + reciente actividad + ciertos grupos categóricos.
#
#    **Caso B – cerca del umbral F1**
#    Contribuciones mixtas: `customer_type_nan` +2.76, `region_id_80` +0.89, pero `prod_prior_rate` −0.68, `cp_recency` −0.53, `cp_prev_bought` −0.16.
#    Lectura: hay fuerzas en direcciones opuestas. Aunque los categóricos (faltante en tipo y región 80) empujan a favor, la recencia desfavorable (tiempo sin compra) y una tasa previa baja tiran en contra. Por eso la predicción queda “en el borde” del umbral.
#
#    **Caso C – probabilidad baja**
#    Contribuciones principales (negativas): `customer_type_nan` −4.23, `region_id_80` −1.35, `region_id_nan` −0.32, `cp_recency` −0.27, `prod_prior_rate` −0.13.
#    Lectura: aquí el mismo atributo `customer_type_nan` actúa en contra (gran magnitud negativa). Sumado a recencia y ratio previo desfavorables, el conjunto aplasta la probabilidad. Este contraste A↔C evidencia que el modelo usa la falta de tipo de cliente como un potente modificador… en ambas direcciones, lo cual merece auditoría.
#
# 2. **¿Qué atributo es más importante y tiene sentido?**
#
#    Según el barplot/tabla de importancia global:
#    `customer_type_nan` domina (`mean_abs_shap ≈ 3.61`), seguido por `region_id_80` (≈1.15) y señales de comportamiento: `cp_recency`, `prod_prior_rate`, `cp_prev_bought`, `cp_count_12w`, `cp_count_4w`.
#
#    * La preeminencia de recency y tasas previas es totalmente coherente con propensión a compra semanal.
#    * La fuerza de `customer_type_nan` también es coherente si y solo si el faltante no es aleatorio (MNAR): p.ej., ciertos clientes sin tipificación provienen de un canal/implantación donde se compran sistemáticamente algunos SKUs. En la práctica, este hallazgo no debe tomarse como causal, sino como proxy de un patrón operativo.
#
# 3. **¿Hay interacciones relevantes?**
#
#    Tu matriz de interacciones (mean |SHAP_interaction|) destaca:
#
#    * **`cp_recency × customer_type_nan`** (0.138): la recencia pesa más (en módulo) cuando el tipo de cliente está faltante. En los *dependence plots* se aprecia que, dentro del subgrupo `customer_type_nan=1`, pequeñas mejoras/empeoramientos en recency mueven mucho la predicción. Interpretación de negocio: en ese subgrupo, la señal temporal es especialmente informativa (quizá porque la tipificación ausente oculta heterogeneidad que los *lags* capturan indirectamente).
#
#    * **`prod_prior_rate × customer_type_nan`** (0.079): la tasa de compra histórica del SKU adquiere mayor influencia cuando falta el tipo de cliente. Tiene sentido: si el canal/tipo no ayuda a segmentar, el modelo se ancla más en evidencia histórica del propio SKU.
#
#    * **`cp_prev_bought × cp_recency`** (0.065) y **`cp_recency × cp_count_4w/12w`**: patrón clásico de recencia–frecuencia. Haber comprado “la semana pasada” (o recientemente) no tiene el mismo efecto si la frecuencia acumulada es alta o baja; el modelo captura aceleración o enfriamiento del hábito.
#
#    * **`cp_recency × region_id_80`** (0.032): la sensibilidad temporal cambia en la región 80. Esto sugiere diferencias territoriales (logística, surtido, estacionalidad) que modulan el impacto del tiempo desde la última compra.
#
# 4. **¿Existe sesgo hacia algún atributo?**
#
#    Hay dos señales a vigilar:
#
#    1. **Dependencia excesiva de `customer_type_nan`**
#
#       * Hecho: `mean_abs_shap` enorme (3.61) y gap respecto a cualquier categoría informada (`ABARROTES` 0.0315, `MINIMARKET` 0.0056, …).
#       * Riesgo: el modelo puede estar sobre-confiando en la *falta* de tipificación como *proxy* de algo operativo (p.ej., clientes nuevos o de un canal específico). Si en el futuro cambia cómo se registra el tipo (o se completa masivamente), la performance podría derivar.
#       * Mitigaciones:
#
#       * Auditoría de MNAR: ¿qué fracción de clientes con `customer_type` faltante pertenece a ciertos segmentos/zonas/periodos?
#       * Prueba “ablation”: reentrenar sin `customer_type_nan` (o con smoothing agresivo / *target encoding* regularizado) y comparar PR-AUC.
#       * Reglas de negocio: si `customer_type` faltante denota “cliente nuevo”, quizá convenga un modelo/umbral específico para *onboarding*.
#
#    2. **Efecto localizado de `region_id_80`**
#
#       * Hecho: segunda importancia global (1.15) y varias interacciones (con `cp_recency`, `prod_prior_rate`).
#       * Riesgo: que la región 80 esté capturando particularidades (mix de portafolio, promociones, catálogo activo) que no generalizan.
#       * Mitigaciones: validación por región (curvas PR por split geográfico), y revisar drift temporal por región.

# %% [markdown]
# ## 📌 Resultados y Conclusiones [1.0 puntos]
#
# Para finalizar, se deben explicar los desarrollos y resultados obtenidos a lo largo de todo el proceso, desde la selección de las variables hasta la optimización de hiperparámetros e interpretación. Se espera una reflexión crítica sobre el desempeño de los modelos entrenados y una comparación entre los diferentes enfoques. Además, deberán abordar los siguientes puntos clave:
#
# - **Análisis de métricas**: Comenten sobre las métricas obtenidas en cada etapa del modelo, destacando las más relevantes como precisión, recall, F1-score, etc. ¿Cuáles fueron los modelos más efectivos? ¿Qué diferencias notables encontró entre ellos?
#
# - **Impacto de las decisiones tomadas**: Reflexionen sobre cómo las decisiones relacionadas con el preprocesamiento, selección de atributos y optimización de hiperparámetros influyeron en los resultados finales. ¿Hubo alguna decisión que haya tenido un impacto notable en el rendimiento?
#
# - **Lecciones aprendidas**: Concluyan sobre las lecciones más importantes que aprendieron durante el proceso y cómo estas pueden influir en futuras iteraciones del modelo. ¿Qué se podría mejorar si se repitiera el proceso? Si tuvieran más recursos y tiempo, ¿qué otras técnicas/herramientas habrían utilizado?

# %% [markdown]
# ### Resultados y Conclusiones
#
# El objetivo fue priorizar, por cliente y semana, los SKUs con mayor probabilidad de compra. Tras limpiar y estructurar la información en una matriz cliente–producto–semana, diseñar *features* de comportamiento (recencia, frecuencia y tasas históricas) y respetar un holdout temporal con purga, la familia de *boosting* resultó superior. El mejor desempeño se obtuvo con LightGBM:
#
# * VALID: AUC 0.96999, PR-AUC 0.96196, umbral F1=0.3648.
# * TEST : AUC 0.97178, PR-AUC 0.96528.
# * Con ese umbral, clase positiva: *precision* ≈0.876–0.879 y *recall* ≈0.98, elevando el F1 respecto al baseline.
#
# El rendimiento es estable entre VALID y TEST, lo que indica buena generalización en un esquema temporal sin fuga de información.
#
# #### Análisis de métricas
#
# * Métrica principal: PR-AUC (área bajo la curva precisión–recall) por su pertinencia en problemas desbalanceados y porque refleja mejor la calidad de los verdaderos positivos que efectivamente se activan comercialmente.
# * Comparativa de clasificadores (VALID → TEST):
#
#   * LightGBM: PR-AUC 0.9613 → 0.9641 (selección rápida) y 0.9620 → 0.9653 (tuning).
#   * HistGradientBoosting y XGBoost: muy cercanos a LGBM, pero consistentemente por detrás.
#   * RandomForest: correcto pero notablemente menor en PR-AUC.
#   * Regresión logística (baseline): PR-AUC 0.9378 → 0.9361, buen punto de partida pero claramente inferior.
# * Efecto del umbral: optimizar F1 en VALID y trasladarlo a TEST mantiene *precision/recall* en niveles operativos buenos (recall ≈0.98 a costa de cierta caída razonable de *precision*), coherente con el objetivo de no perder compras probables.
#
# #### Impacto de las decisiones tomadas
#
# 1. Pre-procesamiento
#
#    * La consolidación semanal y la eliminación de duplicados permitieron construir un dataset etiquetado coherente con el proceso comercial.
#    * La purga temporal en el holdout evitó fuga y estabilizó las métricas fuera de muestra.
#
# 2. Feature Engineering
#
#    * Las variables de recencia (*cp_recency*), frecuencia (*cp_count_4w/12w*), tasa histórica SKU×cliente (*prod_prior_rate*) y banderas de compra previa resultaron determinantes (valores SHAP elevados).
#    * El tratamiento de categóricas con rare-categories mejoró la robustez al reducir ruido.
#
# 3. Selección de modelo
#
#    * La familia de boosting (LGBM/HGB/XGB) dominó en todas las métricas; LGBM destacó por mejor PR-AUC y tiempo de entrenamiento muy bajo (orden de segundos), lo que facilita iteración y *tuning*.
#
# 4. Optimización de hiperparámetros
#
#    * Mejora modesta pero consistente (+0.07 pp PR-AUC VALID; +0.12 pp TEST) sobre un baseline ya alto.
#    * Los hiperparámetros más influyentes fueron `num_leaves`, `max_depth`, `min_child_samples` (capacidad/regularización del árbol) y el par `learning_rate`–`n_estimators` (capacidad efectiva del ensamble). La rarefacción en OHE aportó estabilidad.
#
# 5. Interpretabilidad
#
#    * SHAP confirmó que comportamiento reciente y hábito son los principales impulsores de compra; además detectó una dependencia fuerte de `customer_type_nan` y `region_id_80`, que podría reflejar patrones operativos y requiere monitoreo (riesgo de sobre-dependencia a faltantes o particularidades regionales).
#
# #### Lecciones aprendidas
#
# * La señal temporal y de hábito domina: recencia, frecuencia y tasas SKU×cliente explican gran parte del poder predictivo.
# * Boosting > modelos lineales: la no linealidad y las interacciones capturadas por LGBM/HGB/XGB aportan varias décimas de PR-AUC frente a la logística.
# * Datos faltantes informativos: los faltantes en `customer_type` concentran mucha importancia. Probablemente no sean aleatorios; conviene mejorar la calidad de tipificación o regularizar su uso para evitar fragilidad si cambia el proceso de captura.
# * Mejoras marginales y sostenibles: con un baseline alto, el *tuning* inteligente aporta décimas valiosas que se traducen en más aciertos en el *top-K* operativo.
#
# #### Qué se podría mejorar en una siguiente iteración
#
# * Métrica operativa: además de PR-AUC, reportar Precision@K / Recall@K por cliente-semana para alinear el modelo a la priorización comercial real (cupos de oferta/llamada).
# * Calibración/segmentación: calibrar umbrales por región o tipo de cliente; evaluar modelos por subpoblación si se confirma heterogeneidad.
# * Más señales: incorporar precio/promoción, stock, estacionalidad, y co-ocurrencia entre SKUs para capturar sustitución/complementariedad.
# * Objetivo de ranking: probar pérdidas *pairwise* (LambdaRank/LightGBM ranker) para ordenar portafolios por cliente.
# * Monitoreo: en producción, seguir drift de distribuciones e importancias SHAP; *re-train* semanal/mensual según ventana deslizante y performance.
# * Cost-sensitive learning: ponderar errores por valor esperado (margen por SKU/cliente) para maximizar impacto económico, no sólo métricas estadísticas.
#
# #### Conclusión
#
# El sistema propuesto logra, de manera personalizada y semanal, priorizar productos con alto poder predictivo y explicabilidad suficiente para su adopción operativa. LightGBM con *features* de comportamiento y un *pipeline* reproducible entrega PR-AUC ≈ 0.965 en TEST y recall ≈ 0.98 en la clase positiva, lo que habilita recomendaciones accionables para el equipo comercial. Las oportunidades de mejora más prometedoras pasan por alinear la optimización a métricas de ranking, reforzar la calidad de datos categóricos y calibrar por subpoblaciones, con un esquema de monitoreo y reentrenamiento que mantenga el desempeño en el tiempo.

# %% [markdown]
# Mucho éxito!
#
# <center>
# <img src="https://media3.giphy.com/media/v1.Y2lkPTc5MGI3NjExaHpvOTY5Z3hpdHI3aDBpdGRueXRqamZncXp2emFrbjJ5M2s5eTR1dSZlcD12MV9pbnRlcm5hbF9naWZfYnlfaWQmY3Q9Zw/1PMVNNKVIL8Ig/giphy.gif" width="300" height="200">
